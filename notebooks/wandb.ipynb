# %%
import wandb

# %%
PROJECT_NAME='DA6401_Assignment_1'

# %%
# Out:
# ---------------------------------------------------------------------------
# CommError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 wandb.init(
#       2     project=PROJECT_NAME,
#       3     name="data_visualization",
#       4 )
#
# File c:\Users\Nagasai\OneDrive\Desktop\Acads\Sem 6\DA6401\Assignment-1\.venv\Lib\site-packages\wandb\sdk\wandb_init.py:1595, in init(entity, project, dir, id, name, notes, tags, config, config_exclude_keys, config_include_keys, allow_val_change, group, job_type, mode, force, reinit, resume, resume_from, fork_from, save_code, tensorboard, sync_tensorboard, monitor_gym, settings, anonymous)
#    1592 if wl:
#    1593     wl._get_logger().exception("error in wandb.init()", exc_info=e)
# -> 1595 get_sentry().reraise(e)
#
# File c:\Users\Nagasai\OneDrive\Desktop\Acads\Sem 6\DA6401\Assignment-1\.venv\Lib\site-packages\wandb\analytics\sentry.py:190, in Sentry.reraise(self, exc)
# ...
